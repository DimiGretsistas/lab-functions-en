# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a > b:
        return a
    elif b > a:
        return b
    else:
        return a

# %%
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.095s
#
# OK

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def greatest(elements):
    largest_element = elements[0]
    for element in elements:
        if element > largest_element:
            largest_element = element
    return largest_element

# %%
elements = [1, 4, 7, 9]
test_largest(greatest, elements )
# Out:
# 9

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(lst):
    total = 0
    for item in lst:
        total += item
    return total

# %%
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.044s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(lst):
    multiplied = 1
    for number in lst:
        multiplied *= number 
    return multiplied

# %%
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.060s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper = "*"):
    if oper == "+":
        total = 0
        for item in arr:
            total += item
        return total
    elif oper == "*":
        multiplied = 1
        for item in arr:
            multiplied *= item
        return multiplied

# %%
test_operations(oper_all, )
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.023s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    result = 1
    for number in range(1, n + 1):
        result *= number
    return result

# %%
#factorial formula
#n! = n * ( n - 1 ) *...*1

# This code defines a function called "factorial" which takes an input "n". The function uses a for loop to iterate through the range of numbers 
# from 1 to n+1. For each number in that range, it multiplies the current value of x by the number in the range. At the end of the loop, 
# the function returns the final value of x, which will be the factorial of the input number "n".

# The Factorial of a positive integer n is the product of all positive integers less than or equal to n. 
# For example, the factorial of 6 (written "6!") is 6 * 5 * 4 * 3 * 2 * 1 = 720.

# So this function takes an input of any positive integer, and returns the factorial of that number.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.025s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(lst_un):
    new_list = []
    for item in lst_un:
        if item in new_list:
            continue
        else:
            new_list.append(item)
    return new_list

# %%
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.052s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    counts = {}
    for item in arr:
        if item in counts:
            counts[item] += 1
        else:
            counts[item] = 1
    
    max_count= 0
    mode = None

    for key in counts:
        if counts[key] > max_count:
            max_count = counts[key]
            mode = key
    return mode

# %%
# This will test your function 

test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.041s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
def st_dev(list_sd):
    total = 0
    count = 0

    for number in list_sd:
        total += number
        count += 1

    mean =  total / count

    sum_of_squares = 0
    for number in list_sd:
        difference = number - mean
        sum_of_squares += difference * difference
    variance = sum_of_squares / (count - 1)
    return variance ** 0.5

# %%
test_stdev(st_dev)
# Out:
# FF.FFF....F....F.F...F.F..F..FF.FF.FF..F..F..F..FF.FFFFFF...F.F.FFFFFF....F.FFF.F..FFF..FFF..FFFFF.F
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 507.1853100943581 != 512.4412567960026 within 5 delta (5.255946701644461 difference) : Should be 512.4412567960026
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 606.2125819819494 != 612.0137915005981 within 5 delta (5.801209518648761 difference) : Should be 612.0137915005981
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 511.53778914389324 != 518.7940067392562 within 5 delta (7.256217595363012 difference) : Should be 518.7940067392562
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 557.1550253046473 != 565.0583282155164 within 5 delta (7.903302910869115 difference) : Should be 565.0583282155164
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 604.5353814582254 != 610.2118945533326 within 5 delta (5.676513095107225 difference) : Should be 610.2118945533326
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 587.611888553627 != 592.7439675532602 within 5 delta (5.132078999633222 difference) : Should be 592.7439675532602
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 628.3854699854929 != 639.1278801041594 within 5 delta (10.742410118666498 difference) : Should be 639.1278801041594
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 526.6555048922714 != 550.073734726867 within 5 delta (23.418229834595536 difference) : Should be 550.073734726867
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 568.7087465441272 != 576.1431633451583 within 5 delta (7.434416801031148 difference) : Should be 576.1431633451583
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 526.0528501669164 != 533.3090943253172 within 5 delta (7.256244158400818 difference) : Should be 533.3090943253172
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 491.65966548687584 != 508.91610310541364 within 5 delta (17.256437618537802 difference) : Should be 508.91610310541364
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 601.5980225509536 != 612.246601850784 within 5 delta (10.64857929983043 difference) : Should be 612.246601850784
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError:
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 546.4672417272528 != 573.1396783586798 within 5 delta (26.67243663142699 difference) : Should be 573.1396783586798
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 396.3539327419371 != 417.7937290099027 within 5 delta (21.439796267965562 difference) : Should be 417.7937290099027
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 563.3283035672893 != 574.9445422531347 within 5 delta (11.616238685845474 difference) : Should be 574.9445422531347
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 501.82689969038285 != 510.12212115788867 within 5 delta (8.295221467505826 difference) : Should be 510.12212115788867
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 684.307942376822 != 721.3239062846717 within 5 delta (37.01596390784971 difference) : Should be 721.3239062846717
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 574.6768212559898 != 594.8470231516511 within 5 delta (20.170201895661307 difference) : Should be 594.8470231516511
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 613.6972630666879 != 620.0569900568555 within 5 delta (6.359726990167587 difference) : Should be 620.0569900568555
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 580.6926725968646 != 586.4708514562707 within 5 delta (5.778178859406125 difference) : Should be 586.4708514562707
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 540.4353280855635 != 547.1490678407708 within 5 delta (6.713739755207371 difference) : Should be 547.1490678407708
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 557.0385896865674 != 562.693948785661 within 5 delta (5.655359099093516 difference) : Should be 562.693948785661
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 657.426106451354 != 662.542340083897 within 5 delta (5.116233632542958 difference) : Should be 662.542340083897
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 606.0133989190515 != 620.2744888824959 within 5 delta (14.26108996344442 difference) : Should be 620.2744888824959
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 591.1406915402891 != 596.7976691559833 within 5 delta (5.656977615694132 difference) : Should be 596.7976691559833
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 480.54913611640404 != 490.8847085634765 within 5 delta (10.33557244707248 difference) : Should be 490.8847085634765
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 630.7309521108166 != 649.0167953555554 within 5 delta (18.28584324473877 difference) : Should be 649.0167953555554
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/dimitriosgretsistas/Desktop/AI-ENG-BOOTCAMP/Week 1/Tuesday  Labs/lab-functions-en/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 562.9206632645437 != 570.4769834272012 within 5 delta (7.556320162657471 difference) : Should be 570.4769834272012
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.033s
#
# FAILED (failures=53)

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    found = ""
    count = 0

    for char in string:
        char = char.lower()

        if 'a' <= char <= 'z':
            if char not in found:
                found += char
                count += 1
    return count == 26

# %%
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.004s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    words_list = []
    word = ""

    for char in string:
        if char != ",":
            if char != " ":
                word += char
        elif char == ",":
            words_list.append(word)
            word = ""

    words_list.append(word)
    sorted_words = sorted(words_list, key = str.lower)

    result = ""
    for i in range(len(sorted_words)):
        result += sorted_words[i]
        if i != len(sorted_words) -1:
            result += ","
    return result

# %%
test_alpha(sort_alpha)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.026s
#
# OK

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.

# %%
def check_pass(password: str):
    if len(password) < 8:
        return False
    
    has_lower = False
    has_upper = False
    has_digit = False
    has_special = False

    for char in password:
        if 'a' <= char <= 'z':
            has_lower = True
        if 'A' <= char <= 'Z':
            has_upper = True
        if '0' <= char <= '9':
            has_digit = True
        if not ('a' <= char <= 'z' or 'A' <= char <= 'Z' or '0' <= char <= '9'):
            has_special = True
        
    if has_lower and has_upper and has_digit and has_special:
         return True
    
    return False

# %%
test_pass(check_pass)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.022s
#
# OK
